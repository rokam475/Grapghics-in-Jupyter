# %% [markdown]
# # Hello This is an intro
# Table of contents:
# * hello world

# %%
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\python\python395\lib\site-packages (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\python395\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\python\python395\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\python\python395\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python395\lib\site-packages (from matplotlib) (4.29.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\python395\lib\site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python395\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\python395\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\python\python395\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\python\python395\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib

# %%
def func(x,y):
    y = a*x + b
    return y

# %%
a = 10
b = 5

# %%
func(3,3)
# Out:
# 35

# %%
a=6
b=10

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import random
import matplotlib.pyplot as plt

x = list(range(10))
y = list(reversed(range(10)))

# %%
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="432">
