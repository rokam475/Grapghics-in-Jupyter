# %% [markdown]
# # Programming Project #1: Hybrid Images
# ## CS445: Computational Photography
# ### Part I: Hybrid Images

# %% [markdown]
# # Image Set Up

# %%
import cv2

import numpy as np
from matplotlib.colors import LogNorm
from scipy import signal

import utils

# %matplotlib notebook  
import matplotlib.pyplot as plt

lowIm_file = 'nutmeg.jpg'
hiIm_file = 'DerekPicture.jpg'

lowIm = np.float32(cv2.imread(lowIm_file, cv2.IMREAD_GRAYSCALE) / 255.0)
hiIm = np.float32(cv2.imread(hiIm_file, cv2.IMREAD_GRAYSCALE) / 255.0)

pts_im1 = utils.prompt_eye_selection(lowIm)

pts_im2 = utils.prompt_eye_selection(hiIm)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
lowIm, hiIm = utils.align_images(lowIm_file, hiIm_file,pts_im1,pts_im2,save_images=False)

# convert to grayscale
lowIm = cv2.cvtColor(lowIm, cv2.COLOR_BGR2GRAY) / 255.0
hiIm = cv2.cvtColor(hiIm, cv2.COLOR_BGR2GRAY) / 255.0

#Images sanity check
fig, axes = plt.subplots(1, 2)
axes[0].imshow(lowIm,cmap='gray')
axes[0].set_title('Low Img'), axes[0].set_xticks([]), axes[0].set_yticks([])
axes[1].imshow(hiIm,cmap='gray')
axes[1].set_title('Hi Img'), axes[1].set_xticks([]), axes[1].set_yticks([]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 lowIm, hiIm = utils.align_images(lowIm_file, hiIm_file,pts_im1,pts_im2,save_images=False)
#       3 # convert to grayscale
#       4 lowIm = cv2.cvtColor(lowIm, cv2.COLOR_BGR2GRAY) / 255.0
#
# File ~\Desktop\jupyter\hybrid\utils.py:31, in align_images(input_img_1, input_img_2, pts_img_1, pts_img_2, save_images)
#      28 center_im1 = np.mean(pts_img_1, axis=0)
#      29 center_im2 = np.mean(pts_img_2, axis=0)
# ---> 31 plt.close('all')
#      33 # translate first so that center of ref points is center of image
#      34 tx = np.around((w1 / 2 - center_im1[0]) * 2).astype(int)
#
# File c:\python\python395\lib\site-packages\matplotlib\pyplot.py:916, in close(fig)
#     914         _pylab_helpers.Gcf.destroy(manager)
#     915 elif fig == 'all':
# --> 916     _pylab_helpers.Gcf.destroy_all()
#     917 elif isinstance(fig, int):
#     918     _pylab_helpers.Gcf.destroy(fig)
#
# File c:\python\python395\lib\site-packages\matplotlib\_pylab_helpers.py:86, in Gcf.destroy_all(cls)
#      84 for manager in list(cls.figs.values()):
#      85     manager.canvas.mpl_disconnect(manager._cidgcf)
# ---> 86     manager.destroy()
#      87 cls.figs.clear()
#      88 gc.collect(1)
#
# File c:\python\python395\lib\site-packages\matplotlib\backends\backend_nbagg.py:130, in FigureManagerNbAgg.destroy(self)
#     128 for comm in list(self.web_sockets):
#     129     comm.on_close()
# --> 130 self.clearup_closed()
#
# File c:\python\python395\lib\site-packages\matplotlib\backends\backend_nbagg.py:138, in FigureManagerNbAgg.clearup_closed(self)
#     134 self.web_sockets = {socket for socket in self.web_sockets
#     135                     if socket.is_open()}
#     137 if len(self.web_sockets) == 0:
# --> 138     self.canvas.close_event()
#
# File c:\python\python395\lib\site-packages\matplotlib\backend_bases.py:1797, in FigureCanvasBase.close_event(self, guiEvent)
#    1795 try:
#    1796     event = CloseEvent(s, self, guiEvent=guiEvent)
# -> 1797     self.callbacks.process(s, event)
#    1798 except (TypeError, AttributeError):
#    1799     pass
#
# File c:\python\python395\lib\site-packages\matplotlib\cbook\__init__.py:292, in CallbackRegistry.process(self, s, *args, **kwargs)
#     290 except Exception as exc:
#     291     if self.exception_handler is not None:
# --> 292         self.exception_handler(exc)
#     293     else:
#     294         raise
#
# File c:\python\python395\lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File c:\python\python395\lib\site-packages\matplotlib\cbook\__init__.py:287, in CallbackRegistry.process(self, s, *args, **kwargs)
#     285 if func is not None:
#     286     try:
# --> 287         func(*args, **kwargs)
#     288     # this does not capture KeyboardInterrupt, SystemExit,
#     289     # and GeneratorExit
#     290     except Exception as exc:
#
# File c:\python\python395\lib\site-packages\matplotlib\backends\backend_nbagg.py:241, in _BackendNbAgg.new_figure_manager_given_figure.<locals>.destroy(event)
#     239 def destroy(event):
#     240     canvas.mpl_disconnect(cid)
# --> 241     Gcf.destroy(manager)
#
# File c:\python\python395\lib\site-packages\matplotlib\_pylab_helpers.py:67, in Gcf.destroy(cls, num)
#      65 if hasattr(manager, "_cidgcf"):
#      66     manager.canvas.mpl_disconnect(manager._cidgcf)
# ---> 67 manager.destroy()
#      68 gc.collect(1)
#
# File c:\python\python395\lib\site-packages\matplotlib\backends\backend_nbagg.py:130, in FigureManagerNbAgg.destroy(self)
#     128 for comm in list(self.web_sockets):
#     129     comm.on_close()
# --> 130 self.clearup_closed()
#
# File c:\python\python395\lib\site-packages\matplotlib\backends\backend_nbagg.py:138, in FigureManagerNbAgg.clearup_closed(self)
#     134 self.web_sockets = {socket for socket in self.web_sockets
#     135                     if socket.is_open()}
#     137 if len(self.web_sockets) == 0:
# --> 138     self.canvas.close_event()
#
# File c:\python\python395\lib\site-packages\matplotlib\backend_bases.py:1797, in FigureCanvasBase.close_event(self, guiEvent)
#    1795 try:
#    1796     event = CloseEvent(s, self, guiEvent=guiEvent)
# -> 1797     self.callbacks.process(s, event)
#    1798 except (TypeError, AttributeError):
#    1799     pass
#
# File c:\python\python395\lib\site-packages\matplotlib\cbook\__init__.py:292, in CallbackRegistry.process(self, s, *args, **kwargs)
#     290 except Exception as exc:
#     291     if self.exception_handler is not None:
# --> 292         self.exception_handler(exc)
#     293     else:
#     294         raise
#
# File c:\python\python395\lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File c:\python\python395\lib\site-packages\matplotlib\cbook\__init__.py:287, in CallbackRegistry.process(self, s, *args, **kwargs)
#     285 if func is not None:
#     286     try:
# --> 287         func(*args, **kwargs)
#     288     # this does not capture KeyboardInterrupt, SystemExit,
#     289     # and GeneratorExit
#     290     except Exception as exc:
#
# File ~\Desktop\jupyter\hybrid\utils.py:161, in prompt_eye_selection.<locals>.onclose(event)
#     160 def onclose(event):
# --> 161     clicked[:, 0] = xs
#     162     clicked[:, 1] = ys
#
# ValueError: could not broadcast input array from shape (0,) into shape (2,)

# %% [markdown]
# # My Functions

# %%
def lowPass(im, sigma):
    lowKern = utils.gaussian_kernel(sigma, 3*sigma)
    filt = cv2.filter2D(src=im, ddepth=-1, kernel=lowKern)
    return filt

def hiPass(im, sigma):
    hiKern = utils.gaussian_kernel(sigma, 3*sigma)
    filt = im - cv2.filter2D(src=im, ddepth=-1, kernel=hiKern)
    return filt

def hybridImage(imLow, imHi, sigma_low, sigma_high):
    '''
    Inputs:
        im1:    RGB (height x width x 3) or a grayscale (height x width) image
                as a numpy array.
        im2:    RGB (height x width x 3) or a grayscale (height x width) image
                as a numpy array.
        sigma_low: standard deviation for the low-pass filter
        sigma_high: standard deviation for the high-pass filter
        
    Output:
        Return the combination of both images, one filtered with a low-pass filter
        and the other with a high-pass filter.
    '''  

    # your code goes here  
#     hiKernImg = im2
#     lowKern = utils.gaussian_kernel(sigma_low, 3*sigma_low)
#     hiKern = utils.gaussian_kernel(sigma_high, 3*sigma_high)
#     im1Filt = cv2.filter2D(src=im1, ddepth=-1, kernel=lowKern)
#     im2Filt = im2 - cv2.filter2D(src=im2, ddepth=-1, kernel=hiKern)
    lowFilt = lowPass(imLow, sigma_low)
    hiFilt = hiPass(imHi, sigma_high)
    return lowFilt + hiFilt

# MY CODE: TEST IMAGES
def showImg(img):
    if isinstance(img, list):
        fig, axes = plt.subplots(1, len(img))
        for i in range(len(img)):
            axes[i].imshow(img[i], cmap='gray')
            axes[i].set_title('Image ' + str(i)), axes[i].set_xticks([]), axes[i].set_yticks([])
        return axes
    
    else:
        fig = plt.figure()
        plt.imshow(img, cmap='gray')
        plt.axis('off')

def label(axes, *argv):
    for i in range(len(argv)):
        axes[i].set_title(argv[i])

# %% [markdown]
# # Testing

# %%
# MY CODE: SIGMA TEST
def imgTester(im1, im2):
    lowSigs = [20, 15, 10, 5, 0]
    hiSigs = [20, 25, 30, 35, 40]
    fig, axes = plt.subplots(1, len(lowSigs))
    for i in range(len(lowSigs)):
        sigma_low = lowSigs[i]
        sigma_high = hiSigs[i]
        im_hybrid = hybridImage(im2, im1, sigma_low, sigma_high)
        axes[i].imshow(im_hybrid,cmap='gray')
imgTester(lowIm, hiIm)

# %% [markdown]
# # Generate Hybrid

# %%
mySigLow = 15
mySigHigh = 25
im_hybrid = hybridImage(hiIm, lowIm, mySigLow, mySigHigh)
showImg(im_hybrid)

# %%
im1Fourier = np.log(np.abs(np.fft.fftshift(np.fft.fft2(lowPass(lowIm, mySigLow)))))
im2Fourier = np.log(np.abs(np.fft.fftshift(np.fft.fft2(hiPass(hiIm, mySigHigh)))))
hybridFourier = np.log(np.abs(np.fft.fftshift(np.fft.fft2(im_hybrid))))
fourierAxes = showImg(im1Fourier, im2Fourier, hybridFourier)
label(fourierAxes, "low_Im", "hi_Im", "hybrid")

# %% [markdown]
# ### Part II: Image Enhancement
# ##### Two out of three types of image enhancement are required.  Choose a good image to showcase each type and implement a method.  This code doesn't rely on the hybrid image part.

# %% [markdown]
# #### Contrast enhancement

# %%
# gamma = 1.5
# im = np.float32(cv2.imread('DerekPicture.jpg', cv2.IMREAD_GRAYSCALE) / 255.0)

gammas = [.5, 1, 1.5]
img = cv2.imread('DerekPicture.jpg',0)
imgs = []
lables = [".5", 1, 1.5]
for gamma in gammas:
    scaledIm = ((im/255) ** (1/gamma)) * 255
    thislist.append(scaledIm)
showImg(imgs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <module>
#       8 for gamma in gammas:
#       9     scaledIm = ((im/255) ** (1/gamma)) * 255
# ---> 10     thislist.append(scaledIm)
#      11 showImg(imgs)
#
# NameError: name 'thislist' is not defined

# %% [markdown]
# #### Color enhancement

# %% [markdown]
# #### Color shift

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<AxesSubplot:title={'center':'Image 0'}>,
#        <AxesSubplot:title={'center':'Image 1'}>], dtype=object)
